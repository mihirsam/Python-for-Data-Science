# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter = {}
    Twitter['Consumer Key'] = 'I3vubtiOaT2EJptxyuGevq1XS'
    Twitter['Consumer Secret'] = 'BmSA5U8uGK0Lkfgyx6QTFAK5NrbtBzVfwgI9JhWF1HLuQk23nN'
    Twitter['Access Token'] = '736562568706150400-kj6WITybiDZtubpXFJQd4Fmx5P19rCe'
    Twitter['Access Token Secret'] = 'bsXSlRroxgZHiQ9t05pmDDPMWDofX2qUC65c0tOCrH3Rv'
    
    with open('secret_twitter_credentials.pkl', 'wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl', 'rb'))

# %%
Twitter = {}
Twitter['Consumer Key'] = 'TYDVp1BaWgUvMOEgfI1DWsBb8'
Twitter['Consumer Secret'] = 'yS4MB8Gu1AgExWPrbV6njwPdn5sK4DSd0onX7zzZvODsI5vNjn'
Twitter['Access Token'] = '736562568706150400-9fKf5su5J6MxZwiRJNxQWgyss0BeBz1'
Twitter['Access Token Secret'] = 'pVjXO8DvEOtGmMTKMqtaTnl4BdF9q9Tdq5KSS9txj8tDZ'

# %%
import twitter 

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                          Twitter['Access Token Secret'],
                          Twitter['Consumer Key'],
                          Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)
print(twitter.api)
# Out:
# <module 'twitter.api' from 'C:\\Users\\Xenon\\Anaconda3\\lib\\site-packages\\twitter\\api.py'>

# %%
dlh_woeid = 1

dlh_trends = twitter_api.trends.place(_id=dlh_woeid)

# %%
type(dlh_trends)
# Out:
# twitter.api.TwitterListResponse

# %%
dlh_trends[0]
# Out:
# {'trends': [{'name': '#WhyteChisora2',
#    'url': 'http://twitter.com/search?q=%23WhyteChisora2',
#    'promoted_content': None,
#    'query': '%23WhyteChisora2',
#    'tweet_volume': 15621},
#   {'name': 'Josh Johnson',
#    'url': 'http://twitter.com/search?q=%22Josh+Johnson%22',
#    'promoted_content': None,
#    'query': '%22Josh+Johnson%22',
#    'tweet_volume': None},
#   {'name': '#تمني_الليله',
#    'url': 'http://twitter.com/search?q=%23%D8%AA%D9%85%D9%86%D9%8A_%D8%A7%D9%84%D9%84%D9%8A%D9%84%D9%87',
#    'promoted_content': None,
#    'query': '%23%D8%AA%D9%85%D9%86%D9%8A_%D8%A7%D9%84%D9%84%D9%8A%D9%84%D9%87',
#    'tweet_volume': 33059},
#   {'name': 'Paddy Ashdown',
#    'url': 'http://twitter.com/search?q=%22Paddy+Ashdown%22',
#    'promoted_content': None,
#    'query': '%22Paddy+Ashdown%22',
#    'tweet_volume': 35222},
#   {'name': 'Adrian Peterson',
#    'url': 'http://twitter.com/search?q=%22Adrian+Peterson%22',
#    'promoted_content': None,
#    'query': '%22Adrian+Peterson%22',
#    'tweet_volume': None},
#   {'name': '#FAQSpessebreTV3',
#    'url': 'http://twitter.com/search?q=%23FAQSpessebreTV3',
#    'promoted_content': None,
#    'query': '%23FAQSpessebreTV3',
#    'tweet_volume': 14168},
#   {'name': '#JuveRoma',
#    'url': 'http://twitter.com/search?q=%23JuveRoma',
#    'promoted_content': None,
#    'query': '%23JuveRoma',
#    'tweet_volume': 34361},
#   {'name': '#الشعب_التركي_يتظاهر_ضد_اردوغان',
#    'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B4%D8%B9%D8%A8_%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A_%D9%8A%D8%AA%D8%B8%D8%A7%D9%87%D8%B1_%D8%B6%D8%AF_%D8%A7%D8%B1%D8%AF%D9%88%D8%BA%D8%A7%D9%86',
#    'promoted_content': None,
#    'query': '%23%D8%A7%D9%84%D8%B4%D8%B9%D8%A8_%D8%A7%D9%84%D8%AA%D8%B1%D9%83%D9%8A_%D9%8A%D8%AA%D8%B8%D8%A7%D9%87%D8%B1_%D8%B6%D8%AF_%D8%A7%D8%B1%D8%AF%D9%88%D8%BA%D8%A7%D9%86',
#    'tweet_volume': 22948},
#   {'name': 'Chris Rock',
#    'url': 'http://twitter.com/search?q=%22Chris+Rock%22',
#    'promoted_content': None,
#    'query': '%22Chris+Rock%22',
#    'tweet_volume': None},
#   {'name': 'Aduriz',
#    'url': 'http://twitter.com/search?q=Aduriz',
#    'promoted_content': None,
#    'query': 'Aduriz',
#    'tweet_volume': 15583},
#   {'name': 'Nahir Galarza',
#    'url': 'http://twitter.com/search?q=%22Nahir+Galarza%22',
#    'promoted_content': None,
#    'query': '%22Nahir+Galarza%22',
#    'tweet_volume': None},
#   {'name': 'Damso',
#    'url': 'http://twitter.com/search?q=Damso',
#    'promoted_content': None,
#    'query': 'Damso',
#    'tweet_volume': 17480},
#   {'name': 'Phillip Danault',
#    'url': 'http://twitter.com/search?q=%22Phillip+Danault%22',
#    'promoted_content': None,
#    'query': '%22Phillip+Danault%22',
#    'tweet_volume': None},
#   {'name': 'Joanna Lumley',
#    'url': 'http://twitter.com/search?q=%22Joanna+Lumley%22',
#    'promoted_content': None,
#    'query': '%22Joanna+Lumley%22',
#    'tweet_volume': None},
#   {'name': 'Reid Travis',
#    'url': 'http://twitter.com/search?q=%22Reid+Travis%22',
#    'promoted_content': None,
#    'query': '%22Reid+Travis%22',
#    'tweet_volume': None},
#   {'name': 'David Hogg',
#    'url': 'http://twitter.com/search?q=%22David+Hogg%22',
#    'promoted_content': None,
#    'query': '%22David+Hogg%22',
#    'tweet_volume': 18918},
#   {'name': 'Krakatoa',
#    'url': 'http://twitter.com/search?q=Krakatoa',
#    'promoted_content': None,
#    'query': 'Krakatoa',
#    'tweet_volume': None},
#   {'name': 'Suzane Richthofen',
#    'url': 'http://twitter.com/search?q=%22Suzane+Richthofen%22',
#    'promoted_content': None,
#    'query': '%22Suzane+Richthofen%22',
#    'tweet_volume': None},
#   {'name': 'Wake Forest',
#    'url': 'http://twitter.com/search?q=%22Wake+Forest%22',
#    'promoted_content': None,
#    'query': '%22Wake+Forest%22',
#    'tweet_volume': None},
#   {'name': '#WarringtonFrampton',
#    'url': 'http://twitter.com/search?q=%23WarringtonFrampton',
#    'promoted_content': None,
#    'query': '%23WarringtonFrampton',
#    'tweet_volume': 10259},
#   {'name': '#precure',
#    'url': 'http://twitter.com/search?q=%23precure',
#    'promoted_content': None,
#    'query': '%23precure',
#    'tweet_volume': 18080},
#   {'name': '#FiestOT18',
#    'url': 'http://twitter.com/search?q=%23FiestOT18',
#    'promoted_content': None,
#    'query': '%23FiestOT18',
#    'tweet_volume': None},
#   {'name': '#MOTD',
#    'url': 'http://twitter.com/search?q=%23MOTD',
#    'promoted_content': None,
#    'query': '%23MOTD',
#    'tweet_volume': None},
#   {'name': '#PSGFCN',
#    'url': 'http://twitter.com/search?q=%23PSGFCN',
#    'promoted_content': None,
#    'query': '%23PSGFCN',
#    'tweet_volume': 14355},
#   {'name': '#CARMUN',
#    'url': 'http://twitter.com/search?q=%23CARMUN',
#    'promoted_content': None,
#    'query': '%23CARMUN',
#    'tweet_volume': 92394},
#   {'name': '#ArmedForcesBowl',
#    'url': 'http://twitter.com/search?q=%23ArmedForcesBowl',
#    'promoted_content': None,
#    'query': '%23ArmedForcesBowl',
#    'tweet_volume': None},
#   {'name': '#HalaMadrid',
#    'url': 'http://twitter.com/search?q=%23HalaMadrid',
#    'promoted_content': None,
#    'query': '%23HalaMadrid',
#    'tweet_volume': 92025},
#   {'name': '#SCOOM',
#    'url': 'http://twitter.com/search?q=%23SCOOM',
#    'promoted_content': None,
#    'query': '%23SCOOM',
#    'tweet_volume': 10852},
#   {'name': '#chabechristmas',
#    'url': 'http://twitter.com/search?q=%23chabechristmas',
#    'promoted_content': None,
#    'query': '%23chabechristmas',
#    'tweet_volume': None},
#   {'name': '#BugünGünlerdenGALATASARAY',
#    'url': 'http://twitter.com/search?q=%23Bug%C3%BCnG%C3%BCnlerdenGALATASARAY',
#    'promoted_content': None,
#    'query': '%23Bug%C3%BCnG%C3%BCnlerdenGALATASARAY',
#    'tweet_volume': None},
#   {'name': '#JadesICONandIDOLparty',
#    'url': 'http://twitter.com/search?q=%23JadesICONandIDOLparty',
#    'promoted_content': None,
#    'query': '%23JadesICONandIDOLparty',
#    'tweet_volume': None},
#   {'name': '#ONPC',
#    'url': 'http://twitter.com/search?q=%23ONPC',
#    'promoted_content': None,
#    'query': '%23ONPC',
#    'tweet_volume': None},
#   {'name': '#L6Nalmeida',
#    'url': 'http://twitter.com/search?q=%23L6Nalmeida',
#    'promoted_content': None,
#    'query': '%23L6Nalmeida',
#    'tweet_volume': None},
#   {'name': '#FiK57',
#    'url': 'http://twitter.com/search?q=%23FiK57',
#    'promoted_content': None,
#    'query': '%23FiK57',
#    'tweet_volume': None},
#   {'name': '#L6Ncrimenlaura',
#    'url': 'http://twitter.com/search?q=%23L6Ncrimenlaura',
#    'promoted_content': None,
#    'query': '%23L6Ncrimenlaura',
#    'tweet_volume': None},
#   {'name': '#WhenIListenToMusic',
#    'url': 'http://twitter.com/search?q=%23WhenIListenToMusic',
#    'promoted_content': None,
#    'query': '%23WhenIListenToMusic',
#    'tweet_volume': None},
#   {'name': '#fcseguefc',
#    'url': 'http://twitter.com/search?q=%23fcseguefc',
#    'promoted_content': None,
#    'query': '%23fcseguefc',
#    'tweet_volume': 10924},
#   {'name': '#ResignTrump',
#    'url': 'http://twitter.com/search?q=%23ResignTrump',
#    'promoted_content': None,
#    'query': '%23ResignTrump',
#    'tweet_volume': 330688},
#   {'name': '#BoicotCensuraTwitter',
#    'url': 'http://twitter.com/search?q=%23BoicotCensuraTwitter',
#    'promoted_content': None,
#    'query': '%23BoicotCensuraTwitter',
#    'tweet_volume': 15431},
#   {'name': '#MHSCOL',
#    'url': 'http://twitter.com/search?q=%23MHSCOL',
#    'promoted_content': None,
#    'query': '%23MHSCOL',
#    'tweet_volume': None},
#   {'name': '#اللهم_انزل_شفاك',
#    'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%84%D9%87%D9%85_%D8%A7%D9%86%D8%B2%D9%84_%D8%B4%D9%81%D8%A7%D9%83',
#    'promoted_content': None,
#    'query': '%23%D8%A7%D9%84%D9%84%D9%87%D9%85_%D8%A7%D9%86%D8%B2%D9%84_%D8%B4%D9%81%D8%A7%D9%83',
#    'tweet_volume': None},
#   {'name': '#ŞenolGüneşİstifa',
#    'url': 'http://twitter.com/search?q=%23%C5%9EenolG%C3%BCne%C5%9F%C4%B0stifa',
#    'promoted_content': None,
#    'query': '%23%C5%9EenolG%C3%BCne%C5%9F%C4%B0stifa',
#    'tweet_volume': None},
#   {'name': '#ASMEAG',
#    'url': 'http://twitter.com/search?q=%23ASMEAG',
#    'promoted_content': None,
#    'query': '%23ASMEAG',
#    'tweet_volume': None},
#   {'name': '#WatershipDown',
#    'url': 'http://twitter.com/search?q=%23WatershipDown',
#    'promoted_content': None,
#    'query': '%23WatershipDown',
#    'tweet_volume': None},
#   {'name': '#L6Ntensióncatalunya',
#    'url': 'http://twitter.com/search?q=%23L6Ntensi%C3%B3ncatalunya',
#    'promoted_content': None,
#    'query': '%23L6Ntensi%C3%B3ncatalunya',
#    'tweet_volume': None},
#   {'name': '#5SOSPOSTER',
#    'url': 'http://twitter.com/search?q=%235SOSPOSTER',
#    'promoted_content': None,
#    'query': '%235SOSPOSTER',
#    'tweet_volume': None},
#   {'name': '#GeceyeNotlarBırakalım',
#    'url': 'http://twitter.com/search?q=%23GeceyeNotlarB%C4%B1rakal%C4%B1m',
#    'promoted_content': None,
#    'query': '%23GeceyeNotlarB%C4%B1rakal%C4%B1m',
#    'tweet_volume': None},
#   {'name': '#NFLnaESPN',
#    'url': 'http://twitter.com/search?q=%23NFLnaESPN',
#    'promoted_content': None,
#    'query': '%23NFLnaESPN',
#    'tweet_volume': None},
#   {'name': '#Prodiges',
#    'url': 'http://twitter.com/search?q=%23Prodiges',
#    'promoted_content': None,
#    'query': '%23Prodiges',
#    'tweet_volume': None},
#   {'name': '#LOSCTFC',
#    'url': 'http://twitter.com/search?q=%23LOSCTFC',
#    'promoted_content': None,
#    'query': '%23LOSCTFC',
#    'tweet_volume': None}],
#  'as_of': '2018-12-29T19:41:47Z',
#  'created_at': '2018-12-22T23:47:53Z',
#  'locations': [{'name': 'Worldwide', 'woeid': 1}]}
