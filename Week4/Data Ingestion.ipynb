# %%
import pandas as pd

# %%
# %ls
# Out:
#  Volume in drive D is Mihir
#  Volume Serial Number is 543B-B921
#
#  Directory of D:\Xenon\Study_Stuffs\Online_Courses\Python for Data Science\Week4
#
# 12/17/2018  05:33 PM    <DIR>          .
# 12/17/2018  05:33 PM    <DIR>          ..
# 12/17/2018  05:10 PM    <DIR>          .ipynb_checkpoints
# 05/29/2017  11:34 PM    <DIR>          __MACOSX
# 12/17/2018  05:33 PM             1,429 Data Ingestion.ipynb
# 12/17/2018  12:13 AM            45,458 IntroToPandas.ipynb
# 12/17/2018  05:22 PM    <DIR>          Week-4-Pandas
#                2 File(s)         46,887 bytes
#                5 Dir(s)  91,373,510,656 bytes free

# %%
# %ls Week-4-Pandas
# Out:
#  Volume in drive D is Mihir
#  Volume Serial Number is 543B-B921
#
#  Directory of D:\Xenon\Study_Stuffs\Online_Courses\Python for Data Science\Week4\Week-4-Pandas
#
# 12/17/2018  05:22 PM    <DIR>          .
# 12/17/2018  05:22 PM    <DIR>          ..
# 05/29/2017  11:34 PM             6,148 .DS_Store
# 12/16/2018  05:10 PM    <DIR>          .ipynb_checkpoints
# 05/27/2017  03:08 AM                 0 Icon
# 12/16/2018  05:10 PM            30,574 Introduction to Pandas.ipynb
# 09/27/2018  02:20 AM    <DIR>          ml-latest-small
# 05/29/2017  11:34 PM    <DIR>          movielens
#                3 File(s)         36,722 bytes
#                5 Dir(s)  91,373,510,656 bytes free

# %%
# %ls {Week-4-Pandas/movielens}
# Out:
# Invalid switch - "/".

# %%
# %cd Week-4-Pandas
# Out:
# D:\Xenon\Study_Stuffs\Online_Courses\Python for Data Science\Week4\Week-4-Pandas

# %%
# %ls
# Out:
#  Volume in drive D is Mihir
#  Volume Serial Number is 543B-B921
#
#  Directory of D:\Xenon\Study_Stuffs\Online_Courses\Python for Data Science\Week4\Week-4-Pandas
#
# 12/17/2018  05:22 PM    <DIR>          .
# 12/17/2018  05:22 PM    <DIR>          ..
# 05/29/2017  11:34 PM             6,148 .DS_Store
# 12/16/2018  05:10 PM    <DIR>          .ipynb_checkpoints
# 05/27/2017  03:08 AM                 0 Icon
# 12/16/2018  05:10 PM            30,574 Introduction to Pandas.ipynb
# 09/27/2018  02:20 AM    <DIR>          ml-latest-small
# 05/29/2017  11:34 PM    <DIR>          movielens
#                3 File(s)         36,722 bytes
#                5 Dir(s)  91,373,510,656 bytes free

# %%
# %ls ml-latest-small
# Out:
#  Volume in drive D is Mihir
#  Volume Serial Number is 543B-B921
#
#  Directory of D:\Xenon\Study_Stuffs\Online_Courses\Python for Data Science\Week4\Week-4-Pandas\ml-latest-small
#
# 09/27/2018  02:20 AM    <DIR>          .
# 09/27/2018  02:20 AM    <DIR>          ..
# 09/27/2018  02:20 AM           197,979 links.csv
# 09/27/2018  02:19 AM           494,431 movies.csv
# 09/27/2018  02:19 AM         2,483,723 ratings.csv
# 09/27/2018  02:20 AM             8,342 README.txt
# 09/27/2018  02:19 AM           118,660 tags.csv
#                5 File(s)      3,303,135 bytes
#                2 Dir(s)  91,373,510,656 bytes free

# %%
# !cat ml-latest-small/movies.csv
# Out:
# movieId,title,genres
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# 2,Jumanji (1995),Adventure|Children|Fantasy
# 3,Grumpier Old Men (1995),Comedy|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance
# 5,Father of the Bride Part II (1995),Comedy
# 6,Heat (1995),Action|Crime|Thriller
# 7,Sabrina (1995),Comedy|Romance
# 8,Tom and Huck (1995),Adventure|Children
# 9,Sudden Death (1995),Action
# 10,GoldenEye (1995),Action|Adventure|Thriller
# 11,"American President, The (1995)",Comedy|Drama|Romance
# 12,Dracula: Dead and Loving It (1995),Comedy|Horror
# 13,Balto (1995),Adventure|Animation|Children
# 14,Nixon (1995),Drama
# 15,Cutthroat Island (1995),Action|Adventure|Romance
# 16,Casino (1995),Crime|Drama
# 17,Sense and Sensibility (1995),Drama|Romance
# 18,Four Rooms (1995),Comedy
# 19,Ace Ventura: When Nature Calls (1995),Comedy
# 20,Money Train (1995),Action|Comedy|Crime|Drama|Thriller
# 21,Get Shorty (1995),Comedy|Crime|Thriller
# ...

# %%
# !ls
# Out:
# Icon
# Introduction to Pandas.ipynb
# ml-latest-small
# movielens

# %%
# !cat ml-latest-small/movies.csv | wc -l
# Out:
# 9743

# %%
# !head -5 ./ml-latest-small/movies.csv
# Out:
# movieId,title,genres
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# 2,Jumanji (1995),Adventure|Children|Fantasy
# 3,Grumpier Old Men (1995),Comedy|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance

# %%
# !head -5 ./ml-latest-small/ratings.csv
# Out:
# userId,movieId,rating,timestamp
# 1,1,4.0,964982703
# 1,3,4.0,964981247
# 1,6,4.0,964982224
# 1,47,5.0,964983815

# %% [markdown]
# # Read  CSV with Pandas

# %%
movies = pd.read_csv('./ml-latest-small/movies.csv', sep = ',')
print(type(movies))
movies.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     movieId                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
# 5         6                         Heat (1995)
# 6         7                      Sabrina (1995)
# 7         8                 Tom and Huck (1995)
# 8         9                 Sudden Death (1995)
# 9        10                    GoldenEye (1995)
# 10       11      American President, The (1995)
# 11       12  Dracula: Dead and Loving It (1995)
# 12       13                        Balto (1995)
# 13       14                        Nixon (1995)
# 14       15             Cutthroat Island (1995)
#
#                                          genres
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# ...

# %%
tags = pd.read_csv('./ml-latest-small/tags.csv', sep=',')
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
ratings = pd.read_csv('./ml-latest-small/ratings.csv', sep=',', parse_dates=['timestamp'])
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
del ratings['timestamp']
del tags['timestamp']

# %% [markdown]
# # Data Structure

# %%
print(type(ratings.iloc[0]))
rate0 = ratings.iloc[0]
rate0
# Out:
# <class 'pandas.core.series.Series'>
# userId     1.0
# movieId    1.0
# rating     4.0
# Name: 0, dtype: float64

# %%
rate0.index
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
'rating' in rate0
# Out:
# True

# %%
ratings.index
# Out:
# RangeIndex(start=0, stop=100836, step=1)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
# columns of dataframe become index in series when selected individually

# %%
tags.iloc[[1,5, 10]]
# Out:
#     userId  movieId              tag
# 1        2    60756  Highly quotable
# 5        2    89774        Tom Hardy
# 10      18      431        Al Pacino

# %% [markdown]
# # Descriptive Analysis

# %%
ratings['rating'].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100836.000000  100836.000000  100836.000000
# mean      326.127564   19435.295718       3.501557
# std       182.618491   35530.987199       1.042529
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8122.000000       4.000000
# max       610.000000  193609.000000       5.000000

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000  0.006773 -0.049348
# movieId  0.006773  1.000000 -0.004061
# rating  -0.049348 -0.004061  1.000000

# %%
ratings.mean()
# Out:
# userId       326.127564
# movieId    19435.295718
# rating         3.501557
# dtype: float64

# %%
ratings['rating'].std()
# Out:
# 1.0425292390605359

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# dtype: float64
